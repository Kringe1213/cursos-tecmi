# %% [markdown]
# <a href="https://colab.research.google.com/github/Kringe1213/cursos-tecmi/blob/main/Cajero_atm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Sistema de banco")
int(input("ingrese su cuenta"))
saldo = 2000
cuenta = "3011"
NIP= 1234
intento = (input("ingrese su NIP"))

if(cuenta != "3011"):
  print("intente de nuevo")
  input("ingrese su cuenta")
  if cuenta == 3011:
    print("Bienvenido")


elif(cuenta == "3011"):
  print("Bienvenido")
  input("Ingrese su NIP")
  if NIP == 1234:
    print("Correcto")
  elif NIP != 1234:
    print("Incorrecto")
    input("Ingrese su NIP")
    if NIP == 1234:
      print("Correcto")
# Out:
# Sistema de banco
# ingrese su cuenta3
# ingrese su NIP3
# Bienvenido
# Ingrese su NIP3
# Correcto
