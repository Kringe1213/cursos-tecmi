# %% [markdown]
# <a href="https://colab.research.google.com/github/Kringe1213/cursos-tecmi/blob/main/tecmi_clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Gender = input("Your gender: ")
Name = input("Your name: ")
Age = input("Your age: ")
if Gender = :
print("Hola", Name)
print("Tienes", Age, "años")

# %%
name = input("Give me your name: ")
age= input("Give me your age: ")
print("Hola", name)
print("Tienes", age, "años")
# Out:
# Give me your name: owen
# Give me your age: 17
# Hola owen
# Tienes 17 años

# %%
from typing_extensions import NoDefault

var_1: int(input(("Numero 1")))
var_2: int(input(("Numero 2")))

print("suma")
# Out:
# Numero 1j}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_753/4096408589.py in <cell line: 0>()
#       1 from typing_extensions import NoDefault
#       2
# ----> 3 var_1: int(input(("Numero 1")))
#       4 var_2: int(input(("Numero 2")))
#       5
#
# ValueError: invalid literal for int() with base 10: 'j}'

# %%
age = input("Your age: ")
while (age != "0"):
  print("Incorrect password")
  age= input("Try again: ")

print("Correct password")
print("Welcome")
# Out:
# Your age: 2
# Incorrect password
# Try again: 2
# Incorrect password
# Try again: 2
# Incorrect password
# Try again: 2
# Incorrect password
# Try again: 0
# Correct password
# Welcome

# %%
print("El cuadrado de un numero")
number = int(input("Introduce un numero: "))
print("Resultado :" , number * number)
# Out:
# El cuadrado de un numero
# Introduce un numero: 2
# Resultado : 4

# %%
print("Convertidor Celcius a Fahrenheit:")
Temperatura = float(input("Infresa la temperatura en Celcius:"))
print("La temperatura en Fahrenheit es:", Temperatura * ((9/5) + 32))
# Out:
# Convertidor Celcius a Fahrenheit:
# Infresa la temperatura en Celcius:2
# La temperatura en Fahrenheit es: 67.6

# %%
print("Maquina")
numero = int(input("Introduce un numero:"))

while (True):
  if numero >= 10:
    print("Correcto")
    break
  else:
    print("otro numero")
    numero = int(input("Numero:"))
# Out:
# Maquina
# Introduce un numero:9
# otro numero
# Numero:8
# otro numero
# Numero:99
# Correcto

# %%
print("Sistema de calculador de areas")

print("1. Cuadrado, 2. Triangulo")
print("3. Circulo, 4. Rectangulo")

area = int(input("Figura que desea calcular el area: "))

while(area > 4):
  print("Figura no detectada")
  print("Intente de nuevo")
  area = int(input("Figura que desea calcular el area: "))
  if numero < 4:
    break
if area == 1:
  print("Dame el lado del cuadrado")
  lado = int(input("Lado: "))
  print("El area del cuadrado es:", lado * lado)
if area == 2:
  print("Dame la base del triangulo")
  base = int(input("Base: "))
  print("Dame la altura del triangulo")
  altura = int(input("Altura: "))
  print("El area del triangulo es:", (base * altura) / 2)
if area == 3:
  print("Dame el radio del circulo")
  radio = int(input("Radio: "))
  print("El area del circulo es:", 3.1416 * (radio * radio))
if area == 4:
  print("Dame la base del rectangulo")
  base = int(input("Base:"))
  print("Dame la altura del rectangulo")
  altura = int(input("Altura: "))
  print("El area del rectangulo es", base * altura)
# Out:
# Sistema de calculador de areas
# 1. Cuadrado, 2. Triangulo
# 3. Circulo, 4. Rectangulo
# Figura que desea calcular el area: 4
# Dame la base del rectangulo
# Base:4
# Dame la altura del rectangulo
# Altura: 5
# El area del rectangulo es 20
